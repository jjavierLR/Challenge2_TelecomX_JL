# %% [markdown]
# <a href="https://colab.research.google.com/github/jjavierLR/25023-pre-entrega-jl/blob/main/Borrador_Challenge2_TelecomX_JL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**CHALLENGE 2**
#
#
# ---

# %% [markdown]
# Telecom X - Análisis de Evasión de Clientes
#
# Has sido contratado como asistente de análisis de datos en Telecom X y formarás parte del proyecto "Churn de Clientes". La empresa enfrenta una alta tasa de cancelaciones y necesita comprender los factores que llevan a la pérdida de clientes.
#
# Tu desafío será recopilar, procesar y analizar los datos, utilizando Python y sus principales bibliotecas para extraer información valiosa. A partir de tu análisis, el equipo de Data Science podrá avanzar en modelos predictivos y desarrollar estrategias para reducir la evasión.

# %% [markdown]
# #**1. Extracción de datos**
#
#
# ---

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f11fe382-718d-4786-91a8-2ee1e9a2f08b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f11fe382-718d-4786-91a8-2ee1e9a2f08b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Extrae datos desde TelecomX_Data.json hacia DataFile datos1
try:
    datos1 = pd.read_json('/content/TelecomX_Data.json', encoding='latin-1')
except UnicodeDecodeError:
    try:
        datos1 = pd.read_json('/content/TelecomX_Data.json', encoding='ISO-8859-1')
    except UnicodeDecodeError:
         try:
             datos1 = pd.read_json('/content/TelecomX_Data.json', encoding='cp1252')
         except Exception as e:
             print(f"Could not decode the file with common encodings: {e}")

datos1.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
# Primera columna del DataFile
datos1['customerID']
# Out:
# 0       0002-ORFBO
# 1       0003-MKNFE
# 2       0004-TLHLJ
# 3       0011-IGKFF
# 4       0013-EXCHZ
#            ...
# 7262    9987-LUTYD
# 7263    9992-RRAMN
# 7264    9992-UJOEL
# 7265    9993-LHIEB
# 7266    9995-HOTOH
# Name: customerID, Length: 7267, dtype: object

# %%
# Segunda columna del DataFile
datos1['Churn']
# Out:
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7262     No
# 7263    Yes
# 7264     No
# 7265     No
# 7266     No
# Name: Churn, Length: 7267, dtype: object

# %%
# Normaliza columna customer
datos2 = pd.json_normalize(datos1['customer'])
datos2.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure
# 0  Female              0     Yes        Yes       9
# 1    Male              0      No         No       9
# 2    Male              0      No         No       4
# 3    Male              1     Yes         No      13
# 4  Female              1     Yes         No       3

# %%
# Normaliza columna phone
datos3 = pd.json_normalize(datos1['phone'])
datos3.head()
# Out:
#   PhoneService MultipleLines
# 0          Yes            No
# 1          Yes           Yes
# 2          Yes            No
# 3          Yes            No
# 4          Yes            No

# %%
# Normaliza columna internet
datos4 = pd.json_normalize(datos1['internet'])
datos4.head()
# Out:
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No         Yes
# 1             DSL             No           No               No          No
# 2     Fiber optic             No           No              Yes          No
# 3     Fiber optic             No          Yes              Yes          No
# 4     Fiber optic             No           No               No         Yes
#
#   StreamingTV StreamingMovies
# 0         Yes              No
# 1          No             Yes
# 2          No              No
# 3         Yes             Yes
# 4         Yes              No

# %%
# Normaliza columna account
datos5 = pd.json_normalize(datos1['account'])
datos5.head()
# Out:
#          Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0        One year              Yes      Mailed check             65.6
# 1  Month-to-month               No      Mailed check             59.9
# 2  Month-to-month              Yes  Electronic check             73.9
# 3  Month-to-month              Yes  Electronic check             98.0
# 4  Month-to-month              Yes      Mailed check             83.9
#
#   Charges.Total
# 0         593.3
# 1         542.4
# 2        280.85
# 3       1237.85
# 4         267.4

# %%
# Concatena todos las columnas hacia DataFile datos
datos = pd.concat([datos1['customerID'], datos1['Churn'], datos2, datos3, datos4, datos5], axis = 1)
datos
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
# Muestra columnas del DataFile datos
datos.columns
# Out:
# Index(['customerID', 'Churn', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Charges.Monthly',
#        'Charges.Total'],
#       dtype='object')

# %%
# Muestra cantidad de filas y columnas del DataFile datos
datos.shape
# Out:
# (7267, 21)

# %%
# Muestra información del DataFile datos
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %% [markdown]
# #**2. Transformación de datos**

# %%
# Convierte el tipo de datos de la columna Charges.Total
datos['Charges.Total'] = pd.to_numeric(datos['Charges.Total'], errors='coerce')

# %%
# Muestra información del DataFile datos
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
# Muestra descripción del DataFile datos
datos.describe()
# Out:
#        SeniorCitizen       tenure  Charges.Monthly  Charges.Total
# count    7267.000000  7267.000000      7267.000000    7256.000000
# mean        0.162653    32.346498        64.720098    2280.634213
# std         0.369074    24.571773        30.129572    2268.632997
# min         0.000000     0.000000        18.250000      18.800000
# 25%         0.000000     9.000000        35.425000     400.225000
# 50%         0.000000    29.000000        70.300000    1391.000000
# 75%         0.000000    55.000000        89.875000    3785.300000
# max         1.000000    72.000000       118.750000    8684.800000

# %% [markdown]
# Estas funciones nos ayudan a garantizar que los datos estén limpios y listos para un análisis confiable.
# A continuación veremos ejemplos prácticos de cómo aplicar estas funciones sin modificar el DataFrame original.

# %%
# Verifica valores nulos en cada columna
datos.isnull().sum()
# Out:
# customerID           0
# Churn                0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# Charges.Monthly      0
# Charges.Total       11
# dtype: int64

# %%
# Muestra total de filas por cada valor de la columna tenure
datos.groupby(['tenure'])['tenure'].count()
# Out:
# tenure
# 0      11
# 1     634
# 2     246
# 3     207
# 4     185
#      ...
# 68    104
# 69    100
# 70    122
# 71    176
# 72    369
# Name: tenure, Length: 73, dtype: int64

# %%
# Muestra que las 11 filas de la columna Charges.Total correspondan cuando tenure es 0
condicion = datos['tenure'] == 0
datos[['tenure','Charges.Total']][condicion]
# Out:
#       tenure  Charges.Total
# 975        0            NaN
# 1775       0            NaN
# 1955       0            NaN
# 2075       0            NaN
# 2232       0            NaN
# 2308       0            NaN
# 2930       0            NaN
# 3134       0            NaN
# 3203       0            NaN
# 4169       0            NaN
# 5599       0            NaN

# %%
# Rellena valores nulos con un valor específico
datos['Charges.Total'] = datos['Charges.Total'].fillna(0)

# %%
# Busca valores en blanco con un valor específico
condicion = datos['Churn'] == ''
datos[['tenure','Charges.Total','Churn']][condicion]
# Out:
#       tenure  Charges.Total Churn
# 30        11         929.30
# 75        71        1355.10
# 96        29        1696.20
# 98         5         287.85
# 175       65        6792.45
# ...      ...            ...   ...
# 7158      14         773.20
# 7180      49        2070.75
# 7211       9         684.85
# 7239      67        1372.90
# 7247      31         658.95
#
# [224 rows x 3 columns]

# %%
# Busca valores en blanco con un valor específico
datos['Churn'] = datos['Churn'].replace('','Yes')

# %%
# Busca valores en blanco con un valor específico
condicion = datos['Churn'] == ''
datos[['tenure','Charges.Total','Churn']][condicion]
# Out:
# Empty DataFrame
# Columns: [tenure, Charges.Total, Churn]
# Index: []

# %%
# Muestra que las 11 filas de la columna Charges.Total que corresponden a tenure igual 0 quedaron con valor 0.0
condicion = datos['tenure'] == 0
datos[['tenure','Charges.Total']][condicion]
# Out:
#       tenure  Charges.Total
# 975        0            0.0
# 1775       0            0.0
# 1955       0            0.0
# 2075       0            0.0
# 2232       0            0.0
# 2308       0            0.0
# 2930       0            0.0
# 3134       0            0.0
# 3203       0            0.0
# 4169       0            0.0
# 5599       0            0.0

# %%
# Muestra todas las filas y columnas de DataFile datos
datos
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
# Verifica valores nulos en cada columna
datos.isnull().sum()
# Out:
# customerID          0
# Churn               0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# dtype: int64

# %%
# Muestra descripción del DataFile datos
datos.describe()
# Out:
#        SeniorCitizen       tenure  Charges.Monthly  Charges.Total
# count    7267.000000  7267.000000      7267.000000    7267.000000
# mean        0.162653    32.346498        64.720098    2277.182035
# std         0.369074    24.571773        30.129572    2268.648587
# min         0.000000     0.000000        18.250000       0.000000
# 25%         0.000000     9.000000        35.425000     396.200000
# 50%         0.000000    29.000000        70.300000    1389.200000
# 75%         0.000000    55.000000        89.875000    3778.525000
# max         1.000000    72.000000       118.750000    8684.800000

# %%
# Muestra cantidad de filas del DataFile datos agrupada por la columna tenure
datos.groupby(['tenure'])['tenure'].count()
# Out:
# tenure
# 0      11
# 1     634
# 2     246
# 3     207
# 4     185
#      ...
# 68    104
# 69    100
# 70    122
# 71    176
# 72    369
# Name: tenure, Length: 73, dtype: int64

# %%
# Verifica registros duplicados
datos.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #**3. Carga de datos**

# %%
# Prepara el ambiente para los gráficos
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Estilo de los gráficos
sns.set(style="whitegrid")

# %%
# Genera DataFile datos_gra1 con aquellas filas con columna Churn igual a "Yes" (contratos terminados)
condicion = datos['Churn'] == "Yes"
datos_gra1 = datos[condicion]

# %%
# Genera DataFile datos_gra1 con aquellas filas con columna Churn igual a "No" (contratos vigentes)
condicion = datos['Churn'] == "No"
datos_gra2 = datos[condicion]

# %% [markdown]
# # **PERFIL DE LOS CLIENTES:**

# %% [markdown]
# **POR GÉNERO**

# %%
datos_gra1.groupby(['gender'])['Churn'].count()
# Out:
# gender
# Female    1043
# Male      1050
# Name: Churn, dtype: int64

# %%
# Gráfico de Contratos terminados por Género
datos_gender = datos_gra1.groupby("gender").count()
sns.barplot(data=datos_gender, x="gender", y="Churn", color='green', width=0.4)
plt.title("Contratos terminados por Género")
plt.ylabel("Contratos terminados")
plt.xlabel("Género")
plt.ylim(1035, 1055)
for index, row in datos_gender.iterrows():
    plt.text(x=index, y=row["Churn"] + 0.2, s=row["Churn"], ha='center', va='bottom')

plt.show()

# %%
datos_gra2.groupby(['gender'])['Churn'].count()
# Out:
# gender
# Female    2549
# Male      2625
# Name: Churn, dtype: int64

# %%
# Gráfico de Contratos vigentes por Género
datos_gender = datos_gra2.groupby("gender").count().reset_index()

sns.barplot(data=datos_gender, x="gender", y="Churn", color='orange', width=0.4)
plt.title("Contratos vigentes por Género")
plt.ylabel("Contratos vigentes")
plt.xlabel("Género")
plt.ylim(2300, 2700)  # Ajusta según tus datos reales

# Mostrar valores sobre cada barra
for index, row in datos_gender.iterrows():
    plt.text(x=index, y=row["Churn"] + 0.1, s=row["Churn"], ha='center', va='bottom')

plt.show()

# %% [markdown]
# POR GRUPO ETÁRIO

# %%
datos_gra1.groupby(['SeniorCitizen'])['Churn'].count()

# Agrupación original
serie_edad = datos_gra1.groupby(['SeniorCitizen'])['Churn'].count()

# Renombrar el índice
serie_edad.index = serie_edad.index.map({0: "No Senior", 1: "Senior"})

# Mostrar la Serie
print(serie_edad)
# Out:
# SeniorCitizen
# No Senior    1577
# Senior        516
# Name: Churn, dtype: int64

# %%
# Gráfico de Contratos terminados por Grupo Etario
datos_edad = datos_gra1.groupby("SeniorCitizen").count().reset_index()
# Reemplazar valores para mayor claridad
datos_edad["SeniorCitizen"] = datos_edad["SeniorCitizen"].replace({0: "No Senior", 1: "Senior"})

sns.barplot(data=datos_edad, x="SeniorCitizen", y="Churn", color='#F54927', width=0.4)
plt.title("Contratos terminados por Grupo Etario")
plt.ylabel("Contratos terminados")
plt.xlabel("Grupo Etario")
plt.ylim(400, 1700)  # Ajusta según tus datos reales

# Mostrar valores sobre cada barra
for index, row in datos_edad.iterrows():
    plt.text(x=index, y=row["Churn"] + 0.2, s=row["Churn"], ha='center', va='bottom')

plt.show()

# %%
datos_gra2.groupby(['SeniorCitizen'])['Churn'].count()
# Agrupación original
serie_edad = datos_gra2.groupby(['SeniorCitizen'])['Churn'].count()

# Renombrar el índice
serie_edad.index = serie_edad.index.map({0: "No Senior", 1: "Senior"})

# Mostrar la Serie
print(serie_edad)
# Out:
# SeniorCitizen
# No Senior    4508
# Senior        666
# Name: Churn, dtype: int64

# %%
# Agrupación y transformación
datos_edad = datos_gra2.groupby("SeniorCitizen")["Churn"].count().reset_index()

# Reemplazar valores para mayor claridad
datos_edad["SeniorCitizen"] = datos_edad["SeniorCitizen"].replace({0: "No Senior", 1: "Senior"})

# Gráfico
sns.barplot(data=datos_edad, x="SeniorCitizen", y="Churn", color='#F5EE27', width=0.4)
plt.title("Contratos vigentes por Grupo Etario")
plt.ylabel("Contratos vigentes")
plt.xlabel("Grupo Etario")
plt.ylim(500, 5000)  # Ajusta según tus datos reales

# Mostrar valores sobre cada barra
for index, row in datos_edad.iterrows():
    plt.text(x=index, y=row["Churn"] + 10, s=row["Churn"], ha='center', va='bottom')

plt.show()

# %% [markdown]
# POR PAREJA

# %%
datos_gra1.groupby(['Partner'])['Churn'].count()
# Agrupación original
serie_pareja = datos_gra1.groupby(['Partner'])['Churn'].count()

# Renombrar el índice
serie_pareja.index = serie_pareja.index.map({'Yes': 'En Pareja', 'No': 'Sin Pareja'})

# Mostrar la Serie
print(serie_pareja)
# Out:
# Partner
# Sin Pareja    1308
# En Pareja      785
# Name: Churn, dtype: int64

# %%
# Gráfico de Contratos terminados para clientes en Pareja
datos_pareja = datos_gra1.groupby("Partner")["Churn"].count().reset_index()

# Reemplazar valores para mayor claridad
datos_pareja["Partner"] = datos_pareja["Partner"].replace({"Yes": "En Pareja", "No": "Sin Pareja"})

# Gráfico
sns.barplot(data=datos_pareja, x="Partner", y="Churn", color='#195FB5', width=0.4)
plt.title("Contratos terminados para clientes en Pareja")
plt.ylabel("Contratos terminados")
plt.ylim(400, 1700)  # Ajusta según tus datos reales

# Mostrar valores sobre cada barra
for index, row in datos_pareja.iterrows():
    plt.text(x=index, y=row["Churn"] + 10, s=row["Churn"], ha='center', va='bottom')

plt.show()

# %%
datos_gra2.groupby(['Partner'])['Churn'].count()
# Agrupación original
serie_pareja = datos_gra2.groupby(['Partner'])['Churn'].count()

# Renombrar el índice
serie_pareja.index = serie_pareja.index.map({'Yes': 'En Pareja', 'No': 'Sin Pareja'})

# Mostrar la Serie
print(serie_pareja)
# Out:
# Partner
# Sin Pareja    2441
# En Pareja     2733
# Name: Churn, dtype: int64

# %%
# Agrupación de contratos vigentes por estado de pareja
datos_pareja = datos_gra2.groupby("Partner")["Churn"].count().reset_index()

# Renombrar valores para mayor claridad
datos_pareja["Partner"] = datos_pareja["Partner"].map({'Yes': 'En Pareja', 'No': 'Sin Pareja'})

# Gráfico estilizado
sns.barplot(data=datos_pareja, x="Partner", y="Churn", color='#20B2AA', width=0.4)
plt.title("Contratos vigentes para clientes en Pareja")
plt.ylabel("Contratos vigentes")

# Mostrar valores sobre cada barra
for index, row in datos_pareja.iterrows():
    plt.text(x=index, y=row["Churn"] + 10, s=row["Churn"], ha='center', va='bottom')

plt.show()

# %% [markdown]
# CON DEPENDIENTES

# %%
datos_gra1.groupby(['Dependents'])['Churn'].count()

# Agrupación original
serie_Dependents = datos_gra1.groupby(['Dependents'])['Churn'].count()

# Renombrar el índice
serie_Dependents.index = serie_Dependents.index.map({'Yes': 'Con Dependientes', 'No': 'Sin Dependientes'})

# Mostrar la Serie
print(serie_Dependents)
# Out:
# Dependents
# Sin Dependientes    1696
# Con Dependientes     397
# Name: Churn, dtype: int64

# %%
# Agrupación de contratos terminados por estado de dependientes
datos_dependientes = datos_gra1.groupby("Dependents")["Churn"].count().reset_index()

# Renombrar valores para mayor claridad
datos_dependientes["Dependents"] = datos_dependientes["Dependents"].map({ })

# Gráfico estilizado
sns.barplot(data=datos_dependientes, x="Dependents", y="Churn", color='#B51936', width=0.4)
plt.title("Contratos terminados para clientes con Dependientes")
plt.ylabel("Contratos terminados")
plt.xlabel("Estado de Dependencia")

# Mostrar valores sobre cada barra
for index, row in datos_dependientes.iterrows():
    plt.text(x=index, y=row["Churn"] + 10, s=row["Churn"], ha='center', va='bottom')

plt.show()

# %%
datos_gra2.groupby(['Dependents'])['Churn'].count()

# Agrupación original
serie_Dependents = datos_gra2.groupby(['Dependents'])['Churn'].count()

# Renombrar el índice
serie_Dependents.index = serie_Dependents.index.map({'Yes': 'Con Dependientes', 'No': 'Sin Dependientes'})

# Mostrar la Serie
print(serie_Dependents)
# Out:
# Dependents
# Sin Dependientes    3390
# Con Dependientes    1784
# Name: Churn, dtype: int64

# %%
## Agrupación de contratos vigentes por estado de dependientes
datos_dependientes = datos_gra2.groupby("Dependents")["Churn"].count().reset_index()

# Renombrar valores para mayor claridad
datos_dependientes["Dependents"] = datos_dependientes["Dependents"].map({'Yes': 'Con Dependientes', 'No': 'Sin Dependientes'})

# Gráfico estilizado
sns.barplot(data=datos_dependientes, x="Dependents", y="Churn", color='#5C9677', width=0.4)
plt.title("Contratos vigentes para clientes con Dependientes")
plt.ylabel("Contratos vigentes")

# Mostrar valores sobre cada barra
for index, row in datos_dependientes.iterrows():
    plt.text(x=index, y=row["Churn"] + 10, s=row["Churn"], ha='center', va='bottom')

plt.show()

# %%
datos_gra1.groupby(['tenure'])['Churn'].count()
# Out:
# tenure
# 1     401
# 2     131
# 3     101
# 4      92
# 5      69
#      ...
# 68     13
# 69     13
# 70     14
# 71     12
# 72     13
# Name: Churn, Length: 72, dtype: int64

# %%
# Gráfico de Contratos terminados por Meses Contrato
datos_meses = datos_gra1.groupby("tenure").count()
sns.barplot(data=datos_meses, x="tenure", y="Churn", color="#FFBA3B")
plt.title("Contratos terminados - Mensualizado")
plt.ylabel("Contratos terminados")
plt.xlabel("Cant. Meses")
plt.xticks([1, 12, 24, 36, 48, 60, 72])
plt.show()

# %%
datos_gra2.groupby(['tenure'])['Churn'].count()
# Out:
# tenure
# 0      11
# 1     233
# 2     115
# 3     106
# 4      93
#      ...
# 68     91
# 69     87
# 70    108
# 71    164
# 72    356
# Name: Churn, Length: 73, dtype: int64

# %%
# Gráfico de Contratos vigentes por Meses Contrato
datos_meses = datos_gra2.groupby("tenure").count()
sns.barplot(data=datos_meses, x="tenure", y="Churn", color="#FFBA3B")
plt.title("Contratos Vigentes - Mensualizado")
plt.ylabel("Contratos vigentes")
plt.xlabel("Cant. Meses")
plt.xticks([1, 12, 24, 36, 48, 60, 72])
plt.show()

# %%
# Genera DataFile datos_gra3 con aquellas filas con columna tenure menor o igual a 12 (contratos terminados)
condicion = (datos['Churn'] == "Yes") & (datos['tenure'] <= 12)
datos_gra3 = datos[condicion]

# %%
datos_gra3.groupby(['tenure'])['Churn'].count()
# Out:
# tenure
# 1     401
# 2     131
# 3     101
# 4      92
# 5      69
# 6      45
# 7      56
# 8      49
# 9      52
# 10     47
# 11     33
# 12     40
# Name: Churn, dtype: int64

# %%
# Gráfico de Contratos terminados por Meses Contrato <= 12
datos_meses = datos_gra3.groupby("tenure").count()
sns.barplot(data=datos_meses, x="tenure", y="Churn", color="#FFBA3B")
plt.title("Contratos terminados <=12 Meses")
plt.ylabel("Contratos terminados")
plt.xlabel("Cant. Contrato")
plt.xticks([1, 3, 6, 9, 12])
plt.show()

# %%
# Genera DataFile datos_gra4 con aquellas filas con columna tenure menor o igual a 12 (contratos filar)
condicion = (datos['Churn'] == "No") & (datos['tenure'] <= 12)
datos_gra4 = datos[condicion]

# %%
datos_gra4.groupby(['tenure'])['Churn'].count()
# Out:
# tenure
# 0      11
# 1     233
# 2     115
# 3     106
# 4      93
# 5      69
# 6      70
# 7      80
# 8      81
# 9      73
# 10     71
# 11     68
# 12     79
# Name: Churn, dtype: int64

# %%
# Gráfico de Contratos vigentes por Meses Contrato <= 12
datos_meses = datos_gra4.groupby("tenure").count()
sns.barplot(data=datos_meses, x="tenure", y="Churn", color="#FFBA3B")
plt.title("Contratos vigentes <=12 Meses")
plt.ylabel("Contratos vigentes")
plt.xlabel("Cant. Meses")
plt.xticks([1, 3, 6, 9, 12])
plt.show()

# %%
# Muestra total de filas por cada valor de la columna Churn
datos.groupby(['Churn'])['Churn'].count()
# Out:
# Churn
# No     5174
# Yes    2093
# Name: Churn, dtype: int64

# %%
# Mapa de calor Churn con Perfil de cliente

# Ajustar tamaño de figura
plt.figure(figsize=(10, 6))

# Variables relevantes
servicios = ['tenure', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'Churn']

# Codificación binaria personalizada
datos_bin = datos[servicios].replace({
    'Yes': 1, 'No': 0,
    'Male': 0, 'Female': 1,
    'No internet service': 0,
    'DSL': 1, 'Fiber optic': 1,
    'No phone service': 0
})

# Matriz de correlación
corr = datos_bin.corr()

# Mapa de calor estilizado
sns.heatmap(corr, annot=True, cmap="viridis", center=0, linewidths=0.5, linecolor='white', fmt=".2f", cbar_kws={"shrink": 0.8})
plt.title("Mapa de calor: Churn vs Perfil de Cliente", fontsize=14, fontweight='bold')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-893184004.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   datos_bin = datos[servicios].replace({

# %%
# Mapa de calor Churn con servicios contratados (resumen)
plt.figure(figsize=(10, 6))
servicios = ['PhoneService', 'InternetService', 'Churn']

# Codificación binaria ajustada
datos_bin = datos[servicios].replace({
    'Yes': 1, 'No': 0,
    'No internet service': 0,
    'DSL': 1, 'Fiber optic': 1
})

# Matriz de correlación
corr = datos_bin.corr()

# Mapa de calor estilizado
sns.heatmap(
    corr,
    annot=True,
    cmap="YlGnBu",
    center=0,
    linewidths=0.5,
    linecolor='white',
    fmt=".2f",
    cbar_kws={"shrink": 0.8}
)
plt.title("Mapa de Calor: Churn vs Servicios Contratados", fontsize=14, fontweight='bold')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-167912432.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   datos_bin = datos[servicios].replace({

# %%
# Mapa de calor Churn con servicios contratados (detalle)
plt.figure(figsize=(10, 6))
servicios = [
    'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
    'OnlineBackup', 'DeviceProtection', 'TechSupport',
    'StreamingTV', 'StreamingMovies', 'Churn'
]

# Codificación binaria ajustada
datos_bin = datos[servicios].replace({
    'Yes': 1, 'No': 0,
    'No internet service': 0,
    'DSL': 1, 'Fiber optic': 1,
    'No phone service': 0
})

# Matriz de correlación
corr = datos_bin.corr()

# Mapa de calor estilizado
sns.heatmap(
    corr,
    annot=True,
    cmap="YlGnBu",  # Puedes cambiar a "RdBu", "Spectral", etc.
    center=0,
    linewidths=0.5,
    linecolor='white',
    fmt=".2f",
    cbar_kws={"shrink": 0.8}
)

# Título y etiquetas
plt.title("Mapa de Calor: Churn vs Servicios Contratados (Detalle)", fontsize=14, fontweight='bold')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3839443915.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   datos_bin = datos[servicios].replace({

# %%
# Meses contrato vs Churn
# Gráfico de caja: Meses de contrato vs Churn
plt.figure(figsize=(10, 6))

# Boxplot estilizado
sns.boxplot(
    data=datos,
    x="Churn",
    y="tenure",
    palette={"No": "#4CAF50", "Yes": "#F44336"},  # Verde vs Rojo
    linewidth=1.5
)

# Título y etiquetas
plt.title("Duración del Contrato vs Churn", fontsize=14, fontweight='bold')
plt.xlabel("¿Cliente se dio de baja?", fontsize=12)
plt.ylabel("Meses de contrato", fontsize=12)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1779141117.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
# Tipo de contrato vs Churn
# Gráfico de barras: Tipo de contrato vs Churn
plt.figure(figsize=(10, 6))

# Ordenar categorías
orden_contratos = ["Month-to-month", "One year", "Two year"]

# Gráfico estilizado
sns.countplot(
    data=datos,
    x="Contract",
    hue="Churn",
    order=orden_contratos,
    palette={"No": "#4CAF50", "Yes": "#F44336"}  # Verde vs Rojo
)

# Título y etiquetas
plt.title("Tipo de Contrato vs Churn", fontsize=14, fontweight='bold')
plt.xlabel("Tipo de contrato", fontsize=12)
plt.ylabel("Cantidad de clientes", fontsize=12)
plt.xticks(rotation=0)
plt.legend(title="¿Churn?", title_fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Método de pago vs Churn

# Gráfico de barras: Método de pago vs Churn
plt.figure(figsize=(10, 6))

# Gráfico estilizado
sns.countplot(
    data=datos,
    x="PaymentMethod",
    hue="Churn",
    palette={"No": "#4CAF50", "Yes": "#F44336"}  # Verde vs Rojo
)

# Título y etiquetas
plt.title("Método de Pago vs Churn", fontsize=14, fontweight='bold')
plt.xlabel("Método de pago", fontsize=12)
plt.ylabel("Cantidad de clientes", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend(title="¿Churn?", title_fontsize=12)
plt.tight_layout()
plt.show()
